# %%
from nnvision.utility.measures import get_correlations
from new_load_best import load_model

model, dataloaders = load_model(population='both', neurons_subset='0')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_637450/2428813728.py in <module>
#       2 from new_load_best import load_model
#       3
# ----> 4 model, dataloaders = load_model(population='both', neurons_subset='0')
#
# TypeError: load_model() got an unexpected keyword argument 'neurons_subset'
